# %%
# !python3 send_kinesis.py
# Out:
# {'event_time': '2024-04-01T05:26:17.235183', 'id': 1, 'children': 2, 'payment': 2}
# {'event_time': '2024-04-01T05:26:17.282034', 'id': 1, 'children': 2, 'payment': 2}
# {'event_time': '2024-04-01T05:26:17.291329', 'id': 1, 'children': 2, 'payment': 2}
# {'event_time': '2024-04-01T05:26:17.299212', 'id': 1, 'children': 2, 'payment': 2}
# {'event_time': '2024-04-01T05:26:17.307883', 'id': 1, 'children': 2, 'payment': 2}
# {'event_time': '2024-04-01T05:26:17.317958', 'id': 1, 'children': 2, 'payment': 2}
# {'event_time': '2024-04-01T05:26:17.325906', 'id': 1, 'children': 2, 'payment': 2}
# {'event_time': '2024-04-01T05:26:17.337271', 'id': 1, 'children': 2, 'payment': 2}
# {'event_time': '2024-04-01T05:26:17.350123', 'id': 1, 'children': 2, 'payment': 2}
# {'event_time': '2024-04-01T05:26:17.357386', 'id': 1, 'children': 2, 'payment': 2}
# {'event_time': '2024-04-01T05:26:17.365091', 'id': 1, 'children': 2, 'payment': 2}
# ...
